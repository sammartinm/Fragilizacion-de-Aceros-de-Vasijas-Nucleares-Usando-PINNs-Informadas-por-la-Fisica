# %% [markdown]
# # 01. Uso de Redes Neuronales no Informadas por la Física

# %%
# %load_ext autoreload
# %autoreload 2

from src.dataset.dataset import RadiationDataset
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dataset = RadiationDataset('../data/df_plotter_cm2.csv')
train_set, _, test_set = dataset.data_split(test_factor=0.2)

len(train_set) + len(test_set) - len(dataset)
# Out:
# 0
